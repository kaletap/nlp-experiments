# %% [markdown]
# # Data exploration
# Exploration of data used in 'A Probabilistic Formulation of Unsupervised Text Style Transfer' (https://github.com/cindyxinyiwang/deep-latent-sequence-model).

# %%
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.style.use('fivethirtyeight')
pd.set_option('max_colwidth', 400)

# %% [markdown]
# ## Yelp

# %%
data_path = '../deep-latent-sequence-model/data'
yelp_path = os.path.join(data_path, 'yelp')

# %%
def read_column(path):
    with open(path) as f:
        lines = [line.strip() for line in f.readlines()]
    return lines

# %%
def get_dataset(dataset, split_type='train'):
    root_data_path = '../deep-latent-sequence-model/data'
    data_path = os.path.join(root_data_path, dataset)
    text = read_column(os.path.join(data_path, f'{split_type}.txt'))
    attr = read_column(os.path.join(data_path, f'{split_type}.attr'))
    train_df = pd.DataFrame({'text': text, 'attr': attr})
    return train_df

# %%
yelp_train = get_dataset('yelp', 'train')
yelp_train.head()
# Out:
#                                                               text      attr
# 0                                           i was sadly mistaken .  negative
# 1  so on to the hoagies , the italian is general run of the mill .  negative
# 2                     minimal meat and a ton of shredded lettuce .  negative
# 3   nothing really special & not worthy of the $ _num_ price tag .  negative
# 4                    second , the steak hoagie , it is atrocious .  negative

# %% [markdown]
# ## Shakespeare

# %%
shake_train = get_dataset('shakespeare', 'train')
shake_train.head(10)
# Out:
#                                                                                                                                                            text  \
# 0                                                                                                              I have a mind to strike thee ere thou speak'st .
# 1  Yet if thou say Antony lives , is well , Or friends with Caesar , or not captive to him , I'll set thee in a shower of gold and hail Rich pearls upon thee .
# 2                                                                                                                                           Madam , he's well .
# 3                                                                                                                                                   Well said .
# 4                                                                                                                                     And friends with Caesar .
# 5                                                                                                                                       Th' art an honest man .
# 6                                                                                                                 Caesar and he are greater friends than ever .
# 7                                                                                                                                 Make thee a fortune from me .
# 8                                                                                But yet , madam , I do not like "But yet." It does allay The good precedence .
# 9                                                                       Fie upon "But yet." "But yet" is as a jailer to bring forth Some monstrous malefactor .
#
#        attr
# 0  original
# 1  original
# 2  original
# 3  original
# 4  original
# 5  original
# 6  original
# 7  original
# 8  original
# 9  original

# %% [markdown]
# ## Decipher

# %%
decipher_train = get_dataset('decipher', 'train')
decipher_train.head(10)
# Out:
#                                                                               text  \
# 0                          the pad thai was bland and seemed to lack ingredients .
# 1         she 's pretty happy with both the quality and the quantity of the food .
# 2                        the seats to sit on were either cut open or falling off .
# 3                                                                   good pricing .
# 4                                                      fantastic jalapeo chicken .
# 5                                                              such a great deal !
# 6                             greg and his staff always provide the best service .
# 7  the outdoor seating area on the roof is the perfect outdoor dining experience !
# 8                                                                 excellent food !
# 9                                                          even the kids love it .
#
#        attr
# 0  original
# 1  original
# 2  original
# 3  original
# 4  original
# 5  original
# 6  original
# 7  original
# 8  original
# 9  original

# %%
decipher_train[decipher_train['attr'] != 'original'].head(10)
# Out:
#                                                                                                                                                       text  \
# 200000                                                                                                           __great__ __store__ __to__ __shop__ __!__
# 200001                                                                        __food__ __was__ __so-so__ __and__ __the__ __service__ __was__ __bad__ __.__
# 200002                                                                                               __they__ __have__ __a__ __great__ __selection__ __.__
# 200003                                                                                     __the__ __staff__ __is__ __terrific__ __and__ __helpful__ __.__
# 200004                                                                               __the__ __park__ __is__ __very__ __clean__ __and__ __friendly__ __.__
# 200005                                                                                  __hey__ __chipotle__ __,__ __where__ __is__ __the__ __meat__ __?__
# 200006                                                                                                   __this__ __is__ __the__ __worst__ __store__ __.__
# 200007                                                                                                                                   __perfect__ __!__
# 200008  __unfortunately__ __,__ __the__ __customer__ __service__ __,__ __myself__ __and__ __my__ __group__ __experienced__ __was__ __below__ __par__ __.__
# 200009                                                                                                            __selection__ __is__ __excellent__ __.__
#
#           attr
# 200000  cipher
# 200001  cipher
# 200002  cipher
# 200003  cipher
# 200004  cipher
# 200005  cipher
# 200006  cipher
# 200007  cipher
# 200008  cipher
# 200009  cipher

# %% [markdown]
# ## Sr_bos
# Dataset with serbian and bosnian texts (for unsupervised translation).

# %%
sr_train = get_dataset('sr_bos', 'train')
sr_train.head(10)
# Out:
#                                                                               text  \
# 0      Наводно , одсутни радник је био запослен у Школи са пуним радним временом .
# 1                        У Пониквама су живели само Милан Котлаја и жена му Јока .
# 2  Ми имамо огромно искуство , али смо почели превише приземно да копирамо Запад .
# 3                                          Једном математичарком и пијанисткињом .
# 4                           Тамо није било руских система противваздушне одбране .
# 5                                                  Међупростори су затварани тзв .
# 6         Исто је и са концентрацијама тешких метала – олова , кадмијума и цинка .
# 7  На делатност личности гледао је идеалистички , ван везе с друштвеним условима .
# 8                                   Чланарина за приправне чланове је 500 динара .
# 9                                                 Да су те признали као уметника .
#
#   attr
# 0   sr
# 1   sr
# 2   sr
# 3   sr
# 4   sr
# 5   sr
# 6   sr
# 7   sr
# 8   sr
# 9   sr

# %%
sr_train[sr_train['attr'] != 'sr']
# Out:
#                                                                                                        text  \
# 160000                                      Ljudsko srce uopšte je neobična stvar , a žensko srce osobito !
# 160001                                              Zakon kao zakon , postoji da bi se kršio , i to dobro .
# 160002                      Na farmi je smješteno 95 rasnih krava simentalki uvezenih iz Njemačke i Češke .
# 160003                                     Već su se javili određeni problemi i otpor prema radu agencije .
# 160004                          Anglo-američki odnosi dosegli su najnižu tačku od kraja tridesetih godina .
# ...                                                                                                     ...
# 295888                                     Suštinsko obilježje terorizma jeste politički motiv počinilaca .
# 295889                                         Putem mobilnih timova pravo da glasa imao je 10.181 birača .
# 295890  I pored toga je prohodnost putnih pravaca dobra zahvaljujući intervencijama ekipa putne operative .
# 295891                    Na području općine Živinice poplavljeno je oko 400 Ha poljoprivrednog zemljišta .
# 295892                                Ponedjeljkom od 20h do 22h , uz gostovanje bednova sa živom svirkom .
#
#        attr
# 160000  bos
# 160001  bos
# 160002  bos
# 160003  bos
# 160004  bos
# ...     ...
# 295888  bos
# 295889  bos
# 295890  bos
# 295891  bos
# 295892  bos
#
# [135893 rows x 2 columns]
